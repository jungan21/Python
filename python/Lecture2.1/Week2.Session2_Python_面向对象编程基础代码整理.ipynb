# %% [markdown]
# - 定义一个Student的class

# %%
class Student(object):
    
    def __init__(self, name, score):
        self.name = name
        self.score = score
        
    def speak(self):
        print(self.name, self.score)

# %% [markdown]
# - 创一个Vector class支持加法和乘法

# %%
class Vector(object):
    
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)
    
    def __mul__(self, other):
        return self.x * other.x + self.y * other.y
    
    def __str__(self):
        return "[%s, %s]" % (self.x, self.y)
    
vec1 = Vector(1, 2)
vec2 = Vector(3, 4)
print(vec1 + vec2)
# Out:
# [4, 6]

# %% [markdown]
# - 使用property实现setter

# %%
class Student(object):
    
    def __init__(self, name, score):
        self.name = name
        self.__score = score
        
    @property
    def score(self):
        return self.__score
    
    @score.setter
    def score(self, value):
        assert isinstance(value, int)
        assert 0 <= value <= 99
        self.__score = value
        
        
jack = Student('Jack', 99)
jack.score = 9998
print(jack.score)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-6409f8309862> in <module>()
#      17
#      18 jack = Student('Jack', 99)
# ---> 19 jack.score = 9998
#      20 print(jack.score)
#
# <ipython-input-10-6409f8309862> in score(self, value)
#      12     def score(self, value):
#      13         assert isinstance(value, int)
# ---> 14         assert 0 <= value <= 99
#      15         self.__score = value
#      16
#
# AssertionError:

# %% [markdown]
# - Dog 和 Cat继承来自Animal

# %%
class Animal(object):
    
    def __init__(self, name):
        self.name = name
        self.__color = 'red'
        
    def get_name(self):
        return self.name
    
    def get_color(self):
        return self.__color
    
    def _get_color(self):
        return self.__color    

    def _get_color(self):
        return self.__color  
    
    def speak(self):
        print('LOL')
        
        
class Dog(Animal):
    
    def __init__(self, name):
        Animal.__init__(self, name)
        
        
    def speak(self):
        print(self.name + ': Wow')
    
    
class Cat(Animal):
    
    def __init__(self, name):
        Animal.__init__(self, name)
        
        
    def speak(self):
        print(self.name + ': Mew')
        
        
dog = Dog('WangCai')
dog.speak()

cat = Cat('Ruhua')
cat.speak()
# Out:
# WangCai: Wow
# Ruhua: Mew
